# %%
import pandas as pd
import os
from tensorflow.python.client import device_lib
from keras.models import Sequential, load_model, Model
from keras.layers import Dense, Flatten, Dropout, BatchNormalization
from keras.layers.merge import concatenate
from keras.utils import plot_model
from keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from keras.regularizers import l1, l2, l1_l2
from keras.backend import clear_session

import matplotlib.pyplot as plt

import numpy as np
import sys

from scipy.stats import linregress
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

from math import sqrt
import math
from echoAI.Activation.TF_Keras.custom_activation import CELU

# %% [markdown]
# # Load Data

# %%
data = pd.read_csv('../data/reorganization_energy_data_ECFP4_clean.csv')
data_df = data[data['DFT λ'] > 0].reset_index(drop = False)
data_df = data_df[data_df['DFT λ'] < 2].reset_index(drop = False)
data_df.drop(['level_0','index'], axis = 1, inplace = True)

# %%
print('Number of features (m):',len(data_df.columns))
print('Number of data points (n):',len(data_df))
# Out:
# Number of features (m): 2059
# Number of data points (n): 7681

# %%
data_df.describe()
# Out:
#             ECFP_0       ECFP_1       ECFP_2       ECFP_3       ECFP_4  \
# count  7681.000000  7681.000000  7681.000000  7681.000000  7681.000000
# mean      0.007030     0.014842     0.003645     0.018878     0.021612
# std       0.083557     0.120927     0.060271     0.136102     0.145422
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000     0.000000     0.000000
# 50%       0.000000     0.000000     0.000000     0.000000     0.000000
# 75%       0.000000     0.000000     0.000000     0.000000     0.000000
# max       1.000000     1.000000     1.000000     1.000000     1.000000
#
#             ECFP_5       ECFP_6       ECFP_7       ECFP_8  ECFP_9  ...  \
# count  7681.000000  7681.000000  7681.000000  7681.000000  7681.0  ...
# mean      0.014712     0.019008     0.006249     0.015102     0.0  ...
# std       0.120404     0.136562     0.078810     0.121967     0.0  ...
# min       0.000000     0.000000     0.000000     0.000000     0.0  ...
# 25%       0.000000     0.000000     0.000000     0.000000     0.0  ...
# 50%       0.000000     0.000000     0.000000     0.000000     0.0  ...
# 75%       0.000000     0.000000     0.000000     0.000000     0.0  ...
# max       1.000000     1.000000     1.000000     1.000000     0.0  ...
#
#        Oligomer Length    Monomer 1    Monomer 2  Neutral Angle  Cation Angle  \
# count      7681.000000  7681.000000  7681.000000    7681.000000   7681.000000
# mean          4.106236    65.978779   130.406067     162.090630    166.665720
# std           0.448567    65.827631    88.515075      13.493240     10.624771
# min           4.000000     1.000000     1.000000     103.302165    112.233877
# 25%           4.000000    20.000000    63.000000     154.071801    160.324641
# 50%           4.000000    44.000000    93.000000     165.147859    169.110611
# 75%           4.000000    84.000000   211.000000     172.777791    175.297810
# max           6.000000   312.000000   312.000000     179.950735    179.962772
#
#         Mean Angle  Neutral Bond Length  Cation Bond Length  Mean Bond Length  \
# count  7681.000000          7681.000000         7681.000000       7681.000000
# mean    164.378175             1.422090            1.408446          1.415268
# std      11.808998             0.007752            0.007603          0.007138
# min     109.360120             1.387590            1.381233          1.384852
# 25%     157.129387             1.417525            1.403755          1.411121
# 50%     166.904629             1.422380            1.408263          1.415667
# 75%     173.879653             1.426941            1.412834          1.419845
# max     179.953073             1.449765            1.445235          1.447500
#
#              DFT λ
# count  7681.000000
# mean      0.505517
# std       0.203042
# min       0.014890
# 25%       0.363828
# 50%       0.459584
# 75%       0.603466
# max       1.960507
#
# [8 rows x 2059 columns]

# %% [markdown]
# ### List Features

# %%
cols = list(dict.fromkeys([x.split('_')[0] for x in data_df.drop(['DFT λ'], axis = 1).columns]))

# %%
cols
# Out:
# ['ECFP',
#  'PiSystemSize',
#  'Oligomer Length',
#  'Monomer 1',
#  'Monomer 2',
#  'Neutral Angle',
#  'Cation Angle',
#  'Mean Angle',
#  'Neutral Bond Length',
#  'Cation Bond Length',
#  'Mean Bond Length']

# %% [markdown]
# # Create Training and Test Sets

# %%
X = data_df.drop(['DFT λ'], axis = 1)
y = data_df['DFT λ']

train_X, test_X, train_y, test_y = train_test_split(X, y, test_size=0.15, random_state=420)
n_cols = len(X.columns)

# %% [markdown]
# # Neural Network Model

# %%
def nn_model(n_cols, lambda_l1 = 0.2, lambda_l2 = 0.2, dropout = [0.1369,0.14,0.14], layers = [100,100,100]):
    model = Sequential()
    model.add(Dense(layers[0], kernel_initializer = 'uniform', input_shape=(n_cols,)))
    CELU()
    model.add(BatchNormalization())
    model.add(Dropout(dropout[0]))
    for idx, layer in enumerate(layers[1:]):
        model.add(Dense(layer, kernel_initializer = 'uniform', kernel_regularizer = l2(lambda_l2)))
        CELU()
        model.add(Dropout(dropout[idx+1]))
    model.add(Dense(1, activation='linear'))
    model.compile(optimizer='adam', loss='mean_squared_error', metrics = ['mse', 'mae'])
    return model

# %%
m = nn_model(n_cols, layers = [127, 109], dropout =[0.005,0.488])
m.summary()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-2d86a482e504> in <module>
# ----> 1 m = nn_model(n_cols, layers = [127, 109], dropout =[0.005,0.488])
#       2 m.summary()
#
# <ipython-input-12-4f84c24e1ea3> in nn_model(n_cols, lambda_l1, lambda_l2, dropout, layers)
#       2     model = Sequential()
#       3     model.add(Dense(layers[0], kernel_initializer = 'uniform', input_shape=(n_cols,)))
# ----> 4     CELU()
#       5     model.add(BatchNormalization())
#       6     model.add(Dropout(dropout[0]))
#
# TypeError: __init__() missing 1 required positional argument: 'alpha'

# %%
# %%time
early_stopping_monitor = EarlyStopping(monitor = 'val_loss', 
                                       patience = 150, 
                                       restore_best_weights = True, 
                                       min_delta = 1e-3, 
                                       mode = "min")
mcp_save = ModelCheckpoint('mdl_wts.hdf5', 
                           save_best_only = True, 
                           monitor = 'val_loss', 
                           mode = 'min')
reduce_lr_loss = ReduceLROnPlateau(monitor='val_loss', 
                                   factor = 0.8, 
                                   patience = 50, 
                                   verbose = 1, 
                                   min_delta = 1e-3, 
                                   mode = 'min')
history = m.fit(train_X, train_y, 
                epochs = 1000, 
                callbacks = [ mcp_save, reduce_lr_loss, early_stopping_monitor],
                validation_split = 0.2)
# Out:
# Train on 5227 samples, validate on 1307 samples
# Epoch 1/1000
# 5227/5227 [==============================] - 2s 310us/step - loss: 3.9361 - mse: 2.5842 - mae: 1.0630 - val_loss: 5.2913 - val_mse: 4.5381 - val_mae: 1.0707
# Epoch 2/1000
# 5227/5227 [==============================] - 1s 204us/step - loss: 1.6883 - mse: 1.1838 - mae: 0.5950 - val_loss: 4.1155 - val_mse: 3.8012 - val_mae: 0.6565
# Epoch 3/1000
# 5227/5227 [==============================] - 1s 193us/step - loss: 1.2960 - mse: 1.0780 - mae: 0.5208 - val_loss: 3.8898 - val_mse: 3.7213 - val_mae: 0.6045
# Epoch 4/1000
# 5227/5227 [==============================] - 1s 197us/step - loss: 1.2076 - mse: 1.0850 - mae: 0.5358 - val_loss: 3.7108 - val_mse: 3.6183 - val_mae: 0.5174
# Epoch 5/1000
# 5227/5227 [==============================] - 1s 197us/step - loss: 1.1299 - mse: 1.0452 - mae: 0.5378 - val_loss: 3.6396 - val_mse: 3.5797 - val_mae: 0.4870
# Epoch 6/1000
# 5227/5227 [==============================] - 1s 198us/step - loss: 1.0397 - mse: 0.9814 - mae: 0.4906 - val_loss: 3.8185 - val_mse: 3.7695 - val_mae: 0.6044
# Epoch 7/1000
# 5227/5227 [==============================] - 1s 184us/step - loss: 1.0185 - mse: 0.9624 - mae: 0.4816 - val_loss: 4.0597 - val_mse: 4.0160 - val_mae: 0.7537
# Epoch 8/1000
# 5227/5227 [==============================] - 1s 189us/step - loss:
1000
# 5227/5227 [==============================] - 1s 188us/step - loss: 0.7289 - mse: 0.6801 - mae: 0.3896 - val_loss: 3.7366 - val_mse: 3.6924 - val_mae: 0.6300
# Epoch 191/1000
# 5227/5227 [==============================] - 1s 186us/step - loss: 0.7553 - mse: 0.7007 - mae: 0.4164 - val_loss: 3.6132 - val_mse: 3.5686 - val_mae: 0.5572
# Epoch 192/1000
# 5227/5227 [==============================] - 1s 188us/step - loss: 0.7236 - mse: 0.6736 - mae: 0.4054 - val_loss: 3.6533 - val_mse: 3.6142 - val_mae: 0.6107
# Epoch 193/1000
# 5227/5227 [==============================] - 1s 195us/step - loss: 0.7247 - mse: 0.6806 - mae: 0.3996 - val_loss: 3.7424 - val_mse: 3.6977 - val_mae: 0.6730
# Epoch 194/1000
# 5227/5227 [==============================] - 1s 192us/step - loss: 0.7541 - mse: 0.7037 - mae: 0.4068 - val_loss: 3.5958 - val_mse: 3.5552 - val_mae: 0.5501
# Epoch 195/1000
# 5227/5227 [==============================] - 1s 188us/step - loss: 0.6798 - mse: 0.6440 - mae: 0.3807 - val_loss: 3.7739 - val_mse: 3.7260 - val_mae: 0.6832
# Epoch 196/1000
# 5227/5227 [==============================] - 1s 188us/step - loss: 0.7508 - mse: 0.6861 - mae: 0.4377 - val_loss: 3.6702 - val_mse: 3.6227 - val_mae: 0.5885
# Epoch 197/1000
# 5227/5227 [==============================] - 1s 197us/step - loss: 0.8085 - mse: 0.7610 - mae: 0.3926 - val_loss: 3.6548 - val_mse: 3.6034 - val_mae: 0.5827
# Epoch 198/1000
# 5227/5227 [==============================] - 1s 187us/step - loss: 0.7128 - mse: 0.6707 - mae: 0.3906 - val_loss: 4.2226 - val_mse: 4.1579 - val_mae: 0.8675
# Epoch 199/1000
# 5227/5227 [==============================] - 1s 197us/step - loss: 0.7619 - mse: 0.7140 - mae: 0.3993 - val_loss: 3.7859 - val_mse: 3.7229 - val_mae: 0.6552
# Epoch 200/1000
# 5227/5227 [==============================] - 1s 201us/step - loss: 0.7444 - mse: 0.6753 - mae: 0.4397 - val_loss: 3.6047 - val_mse: 3.5646 - val_mae: 0.5630
# Epoch 201/1000
# 5227/5227 [==============================] - 1s 198us/step - loss: 0.7467 - mse: 0.7105 - mae: 0.3771 - val_loss: 3.6605 - val_mse: 3.6175 - val_mae: 0.6057
# Epoch 202/1000
# 5227/5227 [==============================] - 1s 196us/step - loss: 0.7271 - mse: 0.6687 - mae: 0.4121 - val_loss: 3.7237 - val_mse: 3.6669 - val_mae: 0.6278
# Epoch 203/1000
# 5227/5227 [==============================] - 1s 176us/step - loss: 0.7642 - mse: 0.7079 - mae: 0.4000 - val_loss: 3.6125 - val_mse: 3.5606 - val_mae: 0.5688
#
# Epoch 00203: ReduceLROnPlateau reducing learning rate to 0.0005120000336319208.
# CPU times: user 3min 1s, sys: 12.5 s, total: 3min 13s
# Wall time: 3min 27s

# %%
score = m.evaluate(test_X,test_y)
for index, metric in enumerate(m.metrics_names):
        print("Test {}: {}".format(metric, score[index]))
# Out:
# 1153/1153 [==============================] - 0s 45us/step
# Test loss: 0.33782516742013685
# Test mse: 0.29469722509384155
# Test mae: 0.41150885820388794

# %%
test_y_predictions = np.asarray(m.predict(test_X))

# %%
pdf = test_X[['Oligomer Length','Monomer 1','Monomer 2']].copy(deep=True)
pdf['DFT λ'] = np.asarray(test_y)
pdf['Trained λ'] =  [x for x in list(test_y_predictions)]
pdf['PctDiff'] = (abs(pdf['DFT λ']-pdf['Trained λ'])/pdf['DFT λ'])*100

# %%
print('In the test set there are...')
print('Tetramers: ' + str(len(pdf[pdf['Oligomer Length'] == 4])))
print('Hexamers: ' + str(len(pdf[pdf['Oligomer Length'] == 6])))
# Out:
# In the test set there are...
# Tetramers: 1098
# Hexamers: 55

# %%
fig=plt.figure(figsize=(8, 6), dpi= 300, facecolor='w', edgecolor='k')
plt.grid(color='k', ls = '-.', lw = 0.1)
plt.xlim(0,1.2)
#plt.ylim(0,1)
reg_x = np.arange(0,1.3,0.1)

if len(pdf[pdf['Oligomer Length'] == 4]) > 0:
    tetra_sct = plt.scatter(pdf[pdf['Oligomer Length'] == 4]['Trained λ'], pdf[pdf['Oligomer Length'] == 4]['DFT λ'], s = 30, c = 'tab:blue', edgecolors = 'none', alpha = 0.6, label = "Tetramers")
    slope, intercept, t_r_value, p_value, std_err = linregress(pdf[pdf['Oligomer Length'] == 4]['Trained λ'].astype(np.float),pdf[pdf['Oligomer Length'] == 4]['DFT λ'])
    plt.plot(reg_x,slope*reg_x + intercept, c = 'royalblue', lw = 1, alpha = 0.7)
    t_rmse = sqrt(mean_squared_error(pdf[pdf['Oligomer Length'] == 4]['Trained λ'],pdf[pdf['Oligomer Length'] == 4]['DFT λ']))
    
if len(pdf[pdf['Oligomer Length'] == 6]) > 0:
    hex_sct = plt.scatter(pdf[pdf['Oligomer Length'] == 6]['Trained λ'], pdf[pdf['Oligomer Length'] == 6]['DFT λ'], s = 30, c = 'tab:red', edgecolors = 'none', alpha = 0.6,  label = "Hexamers")
    slope, intercept, h_r_value, p_value, std_err = linregress(pdf[pdf['Oligomer Length'] == 6]['Trained λ'].astype(np.float),pdf[pdf['Oligomer Length'] == 6]['DFT λ'])
    plt.plot(reg_x,slope*reg_x + intercept, c = 'tab:red', lw = 1, alpha = 0.8)
    h_rmse = sqrt(mean_squared_error(pdf[pdf['Oligomer Length'] == 6]['Trained λ'],pdf[pdf['Oligomer Length'] == 6]['DFT λ']))

slope, intercept, total_r_value, p_value, std_err = linregress(pdf['Trained λ'].astype(np.float),pdf['DFT λ'])
total_plt, = plt.plot(reg_x,slope*reg_x + intercept, c = 'gray',ls = '--', lw = 2, alpha = 0.8, label = 'Total')

total_rmse = sqrt(mean_squared_error(pdf['Trained λ'],pdf['DFT λ']))
total = matplotlib.patches.Rectangle((0,0), 1, 1, fill=False, edgecolor='none', visible=False)
plt.xlabel('Trained λ (eV)', fontsize = 18)
plt.ylabel('B3LYP λ (eV)', fontsize = 18)
plt.xticks(fontsize = 16)
plt.yticks(fontsize = 16)

plt.legend([tetra_sct, hex_sct, total], 
           ['Tetramers\n$R^2$ = {:.3f}\nRMSE = {:.3f} eV'.format(t_r_value ** 2, t_rmse), 
            'Hexamers\n$R^2$ = {:.3f}\nRMSE = {:.3f} eV'.format(h_r_value ** 2, h_rmse),
            'Total\n$R^2$ = {:.3f}\nRMSE = {:.3f} eV'.format(total_r_value ** 2, total_rmse),], 
           loc = 8, ncol=3, bbox_to_anchor=(0.49, -0.33), markerscale = 1.5, fontsize = 12, frameon = True)
plt.tight_layout()
#plt.savefig('RF_test_predictions.pdf')
plt.show()
